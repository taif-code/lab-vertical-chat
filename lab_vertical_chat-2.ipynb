# %% [markdown]
# # Vertical Chat
# A sample how to build a chat for small business using:
#
# * GPT 35
# * Panel
# * OpenAI
#
#
# This is just a simple sample to start to understand how the OpenAI API works, and how to create Prompts. It Is really far from beign a complete solution.
# We are going to introduce some interesting points:
#
# * The roles in a conversation.
# * How is the conversations’ memory preserved?
#
# Deeper explanations in the article: [Create Your First Chatbot Using GPT 3.5, OpenAI, Python and Panel.](https://medium.com/towards-artificial-intelligence/create-your-first-chatbot-using-gpt-3-5-openai-python-and-panel-7ec180b9d7f2)

# %%
# !pip install python-dotenv
# !pip install openai

# %%
from dotenv import load_dotenv, find_dotenv
import os
load_dotenv('/content/.env')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
print("✅ OPENAI Key loaded:", OPENAI_API_KEY is not None)
# Out:
# ✅ OPENAI Key loaded: True

# %%
# !pip install openai
from openai import OpenAI

client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

def continue_conversation(messages, temperature=0):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=temperature,
    )
    #print(str(response.choices[0].message["content"]))
    return response.choices[0].message.content

# %%
def add_prompts_conversation(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''

    #Append to the context the User prompt.
    context.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation(context)

    #Add the response to the context.
    context.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
# !pip install jupyter_bokeh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 39.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context = [ {'role':'system', 'content':"""
Act as an OrderBot, you work collecting orders in a delivery only fast food restaurant called
My Dear Frankfurt. \
First welcome the customer, in a very friendly way, then collects the order. \
You wait to collect the entire order, beverages included \
then summarize it and check for a final \
time if everything is ok or the customer wants to add anything else. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very friendly style. \
The menu includes \
burger  12.95, 10.00, 7.00 \
frankfurt   10.95, 9.25, 6.50 \
sandwich   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
martra sausage 3.00 \
canadian bacon 3.50 \
romesco sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
vichy catalan 5.00 \
"""} ]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='241c2db1-1d95-4b1e-8ca9-2ba0eca7fa0b'>
#   <div id="dce51087-a1d4-402b-9119-d3d7b1c64cae" data-root-id="241c2db1-1d95-4b1e-8ca9-2ba0eca7fa0b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
import panel as pn  # GUI

# Context for the Coffee Shop OrderBot
context = [
    {'role':'system', 'content':"""
Act as a CoffeeBot, you work collecting orders in a coffee shop called 'The Perfect Brew'.
First, greet the customer in a very friendly way, then collect their coffee order.
You will ask for the coffee type, size, and any extras.
Then, check if the customer wants to add anything else, such as pastries or drinks.
Once the entire order is taken, summarize it and ask if everything is okay or if the customer wants to add anything else.
Finally, collect the payment information.
Make sure to clarify all options, extras, and sizes to uniquely identify the item from the menu.
You respond in a short, very friendly style.
The menu includes:
Coffee Types:
Espresso  3.50,
Americano 4.00,
Latte 4.50,
Cappuccino 4.00
Sizes:
Small, Medium, Large

Extras:
Extra Shot 1.00,
Almond Milk 1.50,
Caramel Syrup 1.00,
Whipped Cream 0.50

Pastries:
Croissant 2.50,
Muffin 2.00,
Donut 1.50

Drinks:
Water 1.00,
Orange Juice 2.00,
Iced Tea 2.50
"""}
]

# Creating the panel for CoffeeBot

pn.extension()

panels = []

# Input from the user
client_prompt = pn.widgets.TextInput(value="Hello", placeholder='Enter text here…')

# Button for conversation interaction
button_conversation = pn.widgets.Button(name="Order!")

# The function that will manage the conversation (to be added)
interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

# Display the panel with input field and button
dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='89983bbd-aedb-4f72-a59f-bff2340309ef'>
#   <div id="a2116ed0-bc4f-46d5-b500-2fdfd297003a" data-root-id="89983bbd-aedb-4f72-a59f-bff2340309ef" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# Explanation of the CoffeeBot Example:
# Context:
# In the context array, we define a CoffeeBot system that interacts with customers in a coffee shop setting. It collects details such as the coffee type, size, extras (like milk or syrup), and pastries.
# The bot checks if the customer wants to add any additional items, like drinks or snacks, and finally confirms the order before collecting the payment.
# Prompt:
# The prompt is tailored to the coffee shop, specifying the menu and pricing. It’s also highly interactive, collecting details step-by-step: coffee order, size, extras, pastries, and drinks.
# User Interaction:
# The client_prompt widget allows users to type their responses, and the button_conversation is used to trigger the conversation.
# As the user interacts with the bot, the conversation will dynamically update based on the input, showing the conversation in real-time.
# One Page Report on Findings (Summarized):
# Objective:
#
# To experiment with a Coffee Shop OrderBot that collects user coffee orders step-by-step, including coffee types, sizes, extras, and payment.
#
# Steps Followed:
#
# Created CoffeeBot System Context: Defined the bot’s personality and how it should interact with the customer.
# Built GUI with Panel: Set up interactive widgets to accept user inputs, including text input and buttons.
# Collected Coffee Orders: Using Panel’s widgets, we collected details such as coffee type, size, and extras.
# Provided Real-time Feedback: As users interacted, the bot summarized the collected order and confirmed it with the user.
# Handled User Input: We used the bind function (pn.bind) to update the conversation in real-time based on the user's responses.
# Results:
#
# The CoffeeBot performed well, guiding users through the ordering process efficiently.
# It clarified all options, such as coffee type, size, and extras, helping the user make their choices.
# What Worked Well:
#
# Step-by-Step Flow: The flow from greeting the customer to collecting the payment worked seamlessly.
# Real-Time Interaction: Using the panel framework, we were able to maintain a real-time conversation with updates.
# Challenges:
#
# Input Validation: One issue was that the bot didn't check if the input was valid (e.g., confirming the coffee type). Adding such checks could improve the user experience.
# User Flexibility: If a user asked for something outside the specified options, the bot might need additional logic to handle unexpected inputs (e.g., if they request a non-listed coffee).
# Learnings:
#
# Interactive GUIs with Panel: Panel provided a simple yet effective way to create interactive user interfaces.
# User Experience: Step-by-step conversational flow can significantly enhance the user experience when ordering in a chatbot setting.
# Creative Variations:
# Menu Customization: Adding dynamic options based on the user’s previous choices (e.g., upselling additional items like snacks).
# Incorporating Time of Day: The bot could offer special drinks (like morning coffees vs evening teas).
# Payment Handling: Integrating real payment gateways could be a next step to fully automate the coffee ordering process.
# This method of using prompts to guide the chatbot’s responses in real-time using a structured conversational flow is highly effective for interactive ordering bots, whether for food, coffee, or any other service.
